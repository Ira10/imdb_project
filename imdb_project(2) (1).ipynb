# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import

# %%
df1 = pd.read_csv('/content/imdb_movies_data.csv')
df1.head(2)
# Out:
#    ranking                movie_name                                    url  \
# 0        1  The Shawshank Redemption  https://www.imdb.com/title/tt0111161/
# 1        2             The Godfather  https://www.imdb.com/title/tt0068646/
#
#    year  rating vote_count                                            summary  \
# 0  1994     9.3  2,333,043  Two imprisoned men bond over a number of years...
# 1  1972     9.2  1,612,835  An organized crime dynasty's aging patriarch t...
#
#                 production_1        production_2 production_3  ... country_4  \
# 0  Castle Rock Entertainment                                   ...
# 1         Paramount Pictures  Alfran Productions               ...
#
#   language_1 language_2 language_3 language_4 language_5        budget  \
# 0    English                                              $25,000,000
# 1    English    Italian      Latin                         $6,000,000
#
#   gross_worldwide      gross_usa opening_week_usa
# ...

# %% [markdown]
# # EDA

# %%
#deleting unused columns
df1.drop(['production_3','genre_4','movie_length','language_4','language_5','country_3','country_4'], axis=1,inplace=True)
df1.head(2)
# Out:
#    ranking                movie_name                                    url  \
# 0        1  The Shawshank Redemption  https://www.imdb.com/title/tt0111161/
# 1        2             The Godfather  https://www.imdb.com/title/tt0068646/
#
#    year  rating vote_count                                            summary  \
# 0  1994     9.3  2,333,043  Two imprisoned men bond over a number of years...
# 1  1972     9.2  1,612,835  An organized crime dynasty's aging patriarch t...
#
#                 production_1        production_2              director  ...  \
# 0  Castle Rock Entertainment                            Frank Darabont  ...
# 1         Paramount Pictures  Alfran Productions  Francis Ford Coppola  ...
#
#   censor_rating country_1 country_2 language_1 language_2 language_3  \
# 0             A       USA              English
# 1             A       USA              English    Italian      Latin
#
#          budget gross_worldwide      gross_usa opening_week_usa
# ...

# %%
#changing the column name to join with other csv file
df1.rename(columns = {'movie_name' : 'Title'}, inplace=True)
df1.head(1)
# Out:
#    ranking                     Title                                    url  \
# 0        1  The Shawshank Redemption  https://www.imdb.com/title/tt0111161/
#
#    year  rating vote_count                                            summary  \
# 0  1994     9.3  2,333,043  Two imprisoned men bond over a number of years...
#
#                 production_1 production_2        director  ... censor_rating  \
# 0  Castle Rock Entertainment               Frank Darabont  ...             A
#
#   country_1 country_2 language_1 language_2 language_3        budget  \
# 0       USA              English                        $25,000,000
#
#   gross_worldwide     gross_usa opening_week_usa
# 0    $28,817,291   $28,699,976         $727,327
#
# [1 rows x 29 columns]

# %%
df1.shape
# Out:
# (250, 29)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ranking           250 non-null    int64
#  1   Title             250 non-null    object
#  2   url               250 non-null    object
#  3   year              250 non-null    int64
#  4   rating            250 non-null    float64
#  5   vote_count        250 non-null    object
#  6   summary           250 non-null    object
#  7   production_1      250 non-null    object
#  8   production_2      250 non-null    object
#  9   director          250 non-null    object
#  10  writer_1          250 non-null    object
#  11  writer_2          250 non-null    object
#  12  star_1            250 non-null    object
#  13  star_2            250 non-null    object
#  14  star_3            250 non-null    object
#  15  genre_1           250 non-null    object
# ...

# %%
df2= pd.read_csv('/content/IMDB_Top250Engmovies2_OMDB_Detailed.csv')
df2.head(2)
# Out:
#    Unnamed: 0                     Title  Year Rated     Released  Runtime  \
# 0           1  The Shawshank Redemption  1994     R  14 Oct 1994  142 min
# 1           2             The Godfather  1972     R  24 Mar 1972  175 min
#
#           Genre              Director  \
# 0  Crime, Drama        Frank Darabont
# 1  Crime, Drama  Francis Ford Coppola
#
#                                               Writer  \
# 0  Stephen King (short story "Rita Hayworth and S...
# 1  Mario Puzo (screenplay), Francis Ford Coppola ...
#
#                                               Actors  ... tomatoConsensus  \
# 0  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...  ...             NaN
# 1  Marlon Brando, Al Pacino, James Caan, Richard ...  ...             NaN
#
#   tomatoUserMeter tomatoUserRating tomatoUserReviews  \
# 0             NaN              NaN               NaN
# 1             NaN              NaN               NaN
#
# ...

# %%
#deleting unused column and similar column which is present at the first file
df2.drop(['Year','Released','Genre','Director','Writer','Actors','Plot','Language','Country','imdbRating','tomatoMeter','tomatoImage','tomatoRating','tomatoReviews','tomatoFresh','tomatoRotten', 'tomatoConsensus','tomatoUserMeter','tomatoUserRating','tomatoUserReviews','Production','Response'],axis=1,inplace=True)

# %%
df2.shape
# Out:
# (250, 16)

# %%
df2.head(1)
# Out:
#    Unnamed: 0                     Title Rated  Runtime  \
# 0           1  The Shawshank Redemption     R  142 min
#
#                                               Awards  \
# 0  Nominated for 7 Oscars. Another 19 wins & 30 n...
#
#                                               Poster           Ratings.Source  \
# 0  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
#
#   Ratings.Value  Metascore  imdbVotes     imdbID   Type  \
# 0        9.3/10       80.0  1,825,626  tt0111161  movie
#
#                                            tomatoURL          DVD BoxOffice  \
# 0  http://www.rottentomatoes.com/m/shawshank_rede...  27 Jan 1998       NaN
#
#   Website
# 0     NaN

# %%
#df = pd.concat([df1, df2])
#df.head(2)

# %%
#df.shape

# %%
df = pd.merge(df1,df2,on='Title',how='inner')

# %%
df.shape
# Out:
# (161, 44)

# %%
#df.to_csv('file2.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 161 entries, 0 to 160
# Data columns (total 44 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ranking           161 non-null    int64
#  1   Title             161 non-null    object
#  2   url               161 non-null    object
#  3   year              161 non-null    int64
#  4   rating            161 non-null    float64
#  5   vote_count        161 non-null    object
#  6   summary           161 non-null    object
#  7   production_1      161 non-null    object
#  8   production_2      161 non-null    object
#  9   director          161 non-null    object
#  10  writer_1          161 non-null    object
#  11  writer_2          161 non-null    object
#  12  star_1            161 non-null    object
#  13  star_2            161 non-null    object
#  14  star_3            161 non-null    object
#  15  genre_1           161 non-null    object
# ...

# %%
df.drop(['ranking','imdbVotes','Ratings.Value','Ratings.Source','Type'],axis=1,inplace=True)
df.shape
# Out:
# (161, 39)

# %%
# Dropping last n rows using drop
#df.drop(df.tail(88).index,
#        inplace = True)

# %%
df.head(1)
# Out:
#                       Title                                    url  year  \
# 0  The Shawshank Redemption  https://www.imdb.com/title/tt0111161/  1994
#
#    rating vote_count                                            summary  \
# 0     9.3  2,333,043  Two imprisoned men bond over a number of years...
#
#                 production_1 production_2        director      writer_1  ...  \
# 0  Castle Rock Entertainment               Frank Darabont  Stephen King  ...
#
#   Rated  Runtime                                             Awards  \
# 0     R  142 min  Nominated for 7 Oscars. Another 19 wins & 30 n...
#
#                                               Poster Metascore     imdbID  \
# 0  https://images-na.ssl-images-amazon.com/images...      80.0  tt0111161
#
#                                            tomatoURL          DVD BoxOffice  \
# 0  http://www.rottentomatoes.com/m/shawshank_rede...  27 Jan 1998       NaN
#
#   Website
# 0     NaN
#
# [1 rows x 39 columns]

# %%
df.tail(1)
# Out:
#                   Title                                    url  year  rating  \
# 160  The Princess Bride  https://www.imdb.com/title/tt0093779/  1987     8.0
#
#     vote_count                                            summary  \
# 160    392,703  While home sick in bed, a young boy's grandfat...
#
#                production_1          production_2    director  \
# 160  Act III Communications  Buttercup Films Ltd.  Rob Reiner
#
#             writer_1  ... Rated Runtime  \
# 160  William Goldman  ...    PG  98 min
#
#                                                 Awards  \
# 160  Nominated for 1 Oscar. Another 7 wins & 8 nomi...
#
#                                                 Poster Metascore     imdbID  \
# 160  https://images-na.ssl-images-amazon.com/images...      77.0  tt0093779
#
#                                            tomatoURL          DVD BoxOffice  \
# 160  http://www.rottentomatoes.com/m/princess_bride/  26 Jan 1999       NaN
#
# ...

# %%
# Dropping last n rows using drop
#df.drop(df.tail(1).index,
#        inplace = True)

# %%
#dropping unnamed column
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.head(1)
# Out:
#                       Title                                    url  year  \
# 0  The Shawshank Redemption  https://www.imdb.com/title/tt0111161/  1994
#
#    rating vote_count                                            summary  \
# 0     9.3  2,333,043  Two imprisoned men bond over a number of years...
#
#                 production_1 production_2        director      writer_1  ...  \
# 0  Castle Rock Entertainment               Frank Darabont  Stephen King  ...
#
#   Rated  Runtime                                             Awards  \
# 0     R  142 min  Nominated for 7 Oscars. Another 19 wins & 30 n...
#
#                                               Poster Metascore     imdbID  \
# 0  https://images-na.ssl-images-amazon.com/images...      80.0  tt0111161
#
#                                            tomatoURL          DVD BoxOffice  \
# 0  http://www.rottentomatoes.com/m/shawshank_rede...  27 Jan 1998       NaN
#
#   Website
# 0     NaN
#
# [1 rows x 38 columns]

# %%
df.shape
# Out:
# (161, 38)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 161 entries, 0 to 160
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             161 non-null    object
#  1   url               161 non-null    object
#  2   year              161 non-null    int64
#  3   rating            161 non-null    float64
#  4   vote_count        161 non-null    object
#  5   summary           161 non-null    object
#  6   production_1      161 non-null    object
#  7   production_2      161 non-null    object
#  8   director          161 non-null    object
#  9   writer_1          161 non-null    object
#  10  writer_2          161 non-null    object
#  11  star_1            161 non-null    object
#  12  star_2            161 non-null    object
#  13  star_3            161 non-null    object
#  14  genre_1           161 non-null    object
#  15  genre_2           161 non-null    object
# ...

# %%
df[['rating','Rated']]     #pandas is case sensitive
# Out:
#      rating     Rated
# 0       9.3         R
# 1       9.2         R
# 2       9.0         R
# 3       9.0     PG-13
# 4       9.0  APPROVED
# ..      ...       ...
# 156     8.1         R
# 157     8.1         R
# 158     8.1   UNRATED
# 159     8.0     PG-13
# 160     8.0        PG
#
# [161 rows x 2 columns]

# %%
df.select_dtypes(np.number)            #numerical data
# Out:
#      year  rating  Metascore
# 0    1994     9.3       80.0
# 1    1972     9.2      100.0
# 2    1974     9.0       85.0
# 3    2008     9.0       82.0
# 4    1957     9.0       96.0
# ..    ...     ...        ...
# 156  2004     8.1       90.0
# 157  1984     8.1        NaN
# 158  1934     8.1        NaN
# 159  2011     8.0       62.0
# 160  1987     8.0       77.0
#
# [161 rows x 3 columns]

# %%
df.select_dtypes(object)            #categorical data
#why vote count is in object
# Out:
#                         Title                                    url  \
# 0    The Shawshank Redemption  https://www.imdb.com/title/tt0111161/
# 1               The Godfather  https://www.imdb.com/title/tt0068646/
# 2      The Godfather: Part II  https://www.imdb.com/title/tt0071562/
# 3             The Dark Knight  https://www.imdb.com/title/tt0468569/
# 4                12 Angry Men  https://www.imdb.com/title/tt0050083/
# ..                        ...                                    ...
# 156             Before Sunset  https://www.imdb.com/title/tt0381681/
# 157              Paris, Texas  https://www.imdb.com/title/tt0087884/
# 158     It Happened One Night  https://www.imdb.com/title/tt0025316/
# 159                  The Help  https://www.imdb.com/title/tt1454029/
# 160        The Princess Bride  https://www.imdb.com/title/tt0093779/
#
#     vote_count                                            summary  \
# 0    2,333,043  Two imprisoned men bond over a number of years...
# ...

# %%
df[['budget','gross_worldwide','BoxOffice']]
# Out:
#             budget  gross_worldwide     BoxOffice
# 0     $25,000,000      $28,817,291            NaN
# 1      $6,000,000     $246,120,986            NaN
# 2     $13,000,000      $48,035,783            NaN
# 3    $185,000,000   $1,005,973,645   $533,316,061
# 4        $350,000             $576            NaN
# ..             ...              ...           ...
# 156    $2,700,000      $15,936,507     $5,600,000
# 157   GBP1,162,000      $2,206,121            NaN
# 158      $325,000               NaN           NaN
# 159   $25,000,000     $216,639,112   $169,705,587
# 160   $16,000,000      $30,898,633            NaN
#
# [161 rows x 3 columns]

# %%
df.drop(['BoxOffice'],axis=1,inplace=True)

# %%
df.drop(['gross_usa','opening_week_usa','Website','Metascore'],axis=1,inplace=True)

# %%
#dropping empty rows aligned with gross_worldwide percentage which is 2.48
df = df.dropna()

# %%
df.shape
# Out:
# (155, 33)

# %%
#checking for null values
nulls = df.isnull().sum()

# %%
#df.info()

# %%
#to see the percentage of the missing value
nulls_percentage = nulls[nulls!=0]/df.shape[0]*100
print('the percentages of null values per feature:\n')
print(round(nulls_percentage,2))
# Out:
# the percentages of null values per feature:
#
# Series([], dtype: float64)

# %%
df.describe()   # it provides the summary of numerical values.
# Out:
#               year      rating
# count   155.000000  155.000000
# mean   1986.877419    8.317419
# std      22.614309    0.252043
# min    1921.000000    8.000000
# 25%    1975.000000    8.100000
# 50%    1994.000000    8.300000
# 75%    2004.000000    8.400000
# max    2017.000000    9.300000

# %%
df.describe(include='all')     #to check for all
# Out:
#                            Title                                    url  \
# count                        155                                    155
# unique                       155                                    155
# top     The Shawshank Redemption  https://www.imdb.com/title/tt0111161/
# freq                           1                                      1
# mean                         NaN                                    NaN
# std                          NaN                                    NaN
# min                          NaN                                    NaN
# 25%                          NaN                                    NaN
# 50%                          NaN                                    NaN
# 75%                          NaN                                    NaN
# max                          NaN                                    NaN
#
#                year      rating vote_count  \
# count    155.000000  155.000000        155
# ...

# %%
df.nunique()
# Out:
# Title              155
# url                155
# year                69
# rating              13
# vote_count         155
# summary            155
# production_1        80
# production_2        89
# director            90
# writer_1           119
# writer_2           105
# star_1             109
# star_2             142
# star_3             148
# genre_1              9
# genre_2             19
# genre_3             17
# release_date       139
# censor_rating       12
# country_1            9
# country_2           13
# language_1           2
# language_2          26
# language_3          16
# budget              97
# gross_worldwide    154
# Rated                7
# Runtime             87
# Awards             154
# Poster             155
# imdbID             155
# tomatoURL          155
# DVD                134
# dtype: int64

# %%
#data pre processing is done mostly but we need to transform our columns and check data types
#we will check for data visualization now to answer question

# %%
#correlation = df.corr()
#correlation

# %%
df[['Runtime','budget','gross_worldwide']]
# Out:
#      Runtime         budget  gross_worldwide
# 0    142 min   $25,000,000      $28,817,291
# 1    175 min    $6,000,000     $246,120,986
# 2    202 min   $13,000,000      $48,035,783
# 3    152 min  $185,000,000   $1,005,973,645
# 4     96 min      $350,000             $576
# ..       ...            ...              ...
# 155  130 min    $1,288,000          $72,275
# 156   80 min    $2,700,000      $15,936,507
# 157  145 min   GBP1,162,000      $2,206,121
# 159  146 min   $25,000,000     $216,639,112
# 160   98 min   $16,000,000      $30,898,633
#
# [155 rows x 3 columns]

# %%
#replacing $ sign and commas
df["budget"] = df["budget"].str.replace("$", "",regex=False).str.replace(",", "")

# %%
#after replacing there were few cells where 'JPY', 'RUPEES' written, so extracting that
df['budget'] = df['budget'].str.extract('(\d+)', expand=False)
df.head(1)
# Out:
#                       Title                                    url  year  \
# 0  The Shawshank Redemption  https://www.imdb.com/title/tt0111161/  1994
#
#    rating vote_count                                            summary  \
# 0     9.3  2,333,043  Two imprisoned men bond over a number of years...
#
#                 production_1 production_2        director      writer_1  ...  \
# 0  Castle Rock Entertainment               Frank Darabont  Stephen King  ...
#
#   language_3    budget gross_worldwide Rated  Runtime  \
# 0             25000000    $28,817,291      R  142 min
#
#                                               Awards  \
# 0  Nominated for 7 Oscars. Another 19 wins & 30 n...
#
#                                               Poster     imdbID  \
# 0  https://images-na.ssl-images-amazon.com/images...  tt0111161
#
#                                            tomatoURL          DVD
# 0  http://www.rottentomatoes.com/m/shawshank_rede...  27 Jan 1998
#
# ...

# %%
#df.to_csv('file3.csv')

# %%
#after removing character, $, comma, now tuning to string

#df['budget'].astype(int)

#The problem here is that the operation is not functioning inplace that's a reason why the argument copy is part of the function.

#Furthermore, if you want the change to be permanent, you need to re-define your dataframe
df = df.astype({'budget': 'int64'})

# %%
#df["budget"] = [float(str(i).replace("$","").replace(",", "")) for i in df["budget"]]

# %%
#df['budget']

# %%
df["gross_worldwide"] = df["gross_worldwide"].str.replace("$", "",regex=False).str.replace(",", "")

# %%
#df['gross_worldwide'].astype(int)

df = df.astype({'gross_worldwide': int})

# %%
df["vote_count"] = df["vote_count"].str.replace(",", "",regex=False)

df = df.astype({'vote_count': int})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 155 entries, 0 to 160
# Data columns (total 33 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            155 non-null    object
#  1   url              155 non-null    object
#  2   year             155 non-null    int64
#  3   rating           155 non-null    float64
#  4   vote_count       155 non-null    int64
#  5   summary          155 non-null    object
#  6   production_1     155 non-null    object
#  7   production_2     155 non-null    object
#  8   director         155 non-null    object
#  9   writer_1         155 non-null    object
#  10  writer_2         155 non-null    object
#  11  star_1           155 non-null    object
#  12  star_2           155 non-null    object
#  13  star_3           155 non-null    object
#  14  genre_1          155 non-null    object
#  15  genre_2          155 non-null    object
# ...

# %%
df["Runtime"] = df["Runtime"].str.replace("min", "",regex=False)
df['Runtime']
# Out:
# 0      142
# 1      175
# 2      202
# 3      152
# 4       96
#        ...
# 155    130
# 156     80
# 157    145
# 159    146
# 160     98
# Name: Runtime, Length: 155, dtype: object

# %%
df1.rename(columns = {'Runtime' : 'Runtime(mins)'}, inplace=True)

# %%
df[['rating']].mean()
# Out:
# rating    8.317419
# dtype: float64

# %%
# 7 Questions
#1. How big is the data?

df.shape
# Out:
# (155, 33)

# %%
# 2.duplicate

df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 155 entries, 0 to 160
# Data columns (total 33 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            155 non-null    object
#  1   url              155 non-null    object
#  2   year             155 non-null    int64
#  3   rating           155 non-null    float64
#  4   vote_count       155 non-null    int64
#  5   summary          155 non-null    object
#  6   production_1     155 non-null    object
#  7   production_2     155 non-null    object
#  8   director         155 non-null    object
#  9   writer_1         155 non-null    object
#  10  writer_2         155 non-null    object
#  11  star_1           155 non-null    object
#  12  star_2           155 non-null    object
#  13  star_3           155 non-null    object
#  14  genre_1          155 non-null    object
#  15  genre_2          155 non-null    object
# ...

# %%
df.head(2)
# Out:
#                       Title                                    url  year  \
# 0  The Shawshank Redemption  https://www.imdb.com/title/tt0111161/  1994
# 1             The Godfather  https://www.imdb.com/title/tt0068646/  1972
#
#    rating  vote_count                                            summary  \
# 0     9.3     2333043  Two imprisoned men bond over a number of years...
# 1     9.2     1612835  An organized crime dynasty's aging patriarch t...
#
#                 production_1        production_2              director  \
# 0  Castle Rock Entertainment                            Frank Darabont
# 1         Paramount Pictures  Alfran Productions  Francis Ford Coppola
#
#        writer_1  ... language_3    budget gross_worldwide Rated Runtime  \
# 0  Stephen King  ...             25000000        28817291     R    142
# 1    Mario Puzo  ...      Latin   6000000       246120986     R    175
#
#                                               Awards  \
# ...

# %% [markdown]
# ## Visualization

# %%
# Uni-Variate Analysis (independent analysis on each column)
#  Categorical Data
#    1.Count plot

sns.countplot(df['Rated'])      #it helps only when there are less options in column like sex - F, M
df['Rated'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-39b1516eca1e> in <cell line: 5>()
#       3 #    1.Count plot
#       4
# ----> 5 sns.countplot(df['Rated'])      #it helps only when there are less options in column like sex - F, M
#       6 df['Rated'].value_counts()
#
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2941         raise ValueError("Cannot pass values for both `x` and `y`")
#    2942
# -> 2943     plotter = _CountPlotter(
#    2944         x, y, hue, data, order, hue_order,
#    2945         estimator, errorbar, n_boot, units, seed,
#
# ...

# %%
sns.countplot(df['language_1'])      #it helps only when there are less options in column like sex - F, M
df['language_1'].value_counts()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# English    152
# None         3
# Name: language_1, dtype: int64

# %%
plt.figure(figsize=(18,5))
sns.countplot(df['genre_1'])      #it helps only when there are less options in column like sex - F, M

df['genre_1'].value_counts()   #seaborn
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Drama        41
# Action       25
# Crime        24
# Adventure    18
# Biography    16
# Comedy       14
# Animation    10
# Mystery       4
# Horror        3
# Name: genre_1, dtype: int64

# %%
#  Categorical Data
#      2. Pie Chart

plt.figure(figsize=(20,7))
df['genre_1'].value_counts().plot(kind='pie',autopct='%.2f');    #pandas

# %%
#   Numerical Data
#     1.Histogram

plt.hist(df['year'],bins=10)         #this create bins  #matplotlib
# Out:
# (array([ 2.,  6.,  5., 12.,  8., 12., 21., 25., 34., 30.]),
#  array([1921. , 1930.6, 1940.2, 1949.8, 1959.4, 1969. , 1978.6, 1988.2,
#         1997.8, 2007.4, 2017. ]),
#  <a list of 10 Patch objects>)

# %%
#   Numerical Data
#     2.Distplot

sns.distplot(df['year'])    #it has kde - PDF
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#   Numerical Data
#     2.Distplot

sns.distplot(df['Runtime'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(df[df["Runtime"] > 20])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-388-bce70c166482> in <module>
# ----> 1 print(df[df["Runtime"] > 20])
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/arraylike.py in __gt__(self, other)
#      46     @unpack_zerodim_and_defer("__gt__")
#      47     def __gt__(self, other):
# ---> 48         return self._cmp_method(other, operator.gt)
#      49
#      50     @unpack_zerodim_and_defer("__ge__")
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    5500
#    5501         with np.errstate(all="ignore"):
# ...

# %%
#   Numerical Data
#     3.Boxplot

sns.boxplot(df['year']);
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.head(2)
# Out:
#                       Title                                    url  year  \
# 0  The Shawshank Redemption  https://www.imdb.com/title/tt0111161/  1994
# 1             The Godfather  https://www.imdb.com/title/tt0068646/  1972
#
#    rating  vote_count                                            summary  \
# 0     9.3     2333043  Two imprisoned men bond over a number of years...
# 1     9.2     1612835  An organized crime dynasty's aging patriarch t...
#
#                 production_1        production_2              director  \
# 0  Castle Rock Entertainment                            Frank Darabont
# 1         Paramount Pictures  Alfran Productions  Francis Ford Coppola
#
#        writer_1  ... language_3    budget gross_worldwide Rated Runtime  \
# 0  Stephen King  ...             25000000        28817291     R    142
# 1    Mario Puzo  ...      Latin   6000000       246120986     R    175
#
#                                               Awards  \
# ...

# %%
df['budget']=df['budget']/10000
df['gross_worldwide']=df['gross_worldwide']/10000
df[['budget','gross_worldwide']]
# Out:
#       budget  gross_worldwide
# 0     2500.0        2881.7291
# 1      600.0       24612.0986
# 2     1300.0        4803.5783
# 3    18500.0      100597.3645
# 4       35.0           0.0576
# ..       ...              ...
# 155    128.8           7.2275
# 156    270.0        1593.6507
# 157    116.2         220.6121
# 159   2500.0       21663.9112
# 160   1600.0        3089.8633
#
# [155 rows x 2 columns]

# %%
# Bi-Variate Analysis (independent analysis on two columns)
# Multi-Variate Analysis (independent analysis of multi columns)

#   1. Scatter Plot (Numerical - Numerical) - Bivaariate

plt.figure(figsize=(20,7))
sns.scatterplot(df['budget'],df['gross_worldwide'])  #add 'hue' for 3 columns

#add 'style' for 4 column, extra 3,4 columns used for yes, no, two ans
#add 'size' for 5 columns
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#   2. Bar Plot (Numerical - Categorical) - Bivaariate

plt.figure(figsize=(10,7))
sns.barplot(df['country_1'],df['gross_worldwide'],hue=df['language_1']);
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#   2. Bar Plot (Numerical - Categorical) - Bivaariate

plt.figure(figsize=(30,9))
sns.barplot(df['production_1'],df['gross_worldwide'],hue=df['country_1']);
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#   3. Box Plot (Numerical - Categorical) - Bivaariate

plt.figure(figsize=(10,7))
sns.boxplot(df['country_1'],df['gross_worldwide']);
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#   4. Dist Plot (Numerical - Categorical) - Bivaariate

plt.figure(figsize=(10,7))
sns.distplot(df['country_1'],df['gross_worldwide']);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-398-d52a0425830f> in <module>
#       2
#       3 plt.figure(figsize=(10,7))
# ----> 4 sns.distplot(df['country_1'],df['gross_worldwide']);
#
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2634
#    2635     # Make a a 1-d float array
# -> 2636     a = np.asarray(a, float)
#    2637     if a.ndim > 1:
#    2638         a = a.squeeze()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/series.py in __array__(self, dtype)
#     855               dtype='datetime64[ns]')
#     856         """
# --> 857         return np.asarray(self._values, dtype)
#     858
#     859     # ----------------------------------------------------------------------
#
# ...

# %%
#df['budget']=df['budget']/100
#df['gross_worldwide']=df['gross_worldwide']/100
df.head(1)
# Out:
#                       Title                                    url  year  \
# 0  The Shawshank Redemption  https://www.imdb.com/title/tt0111161/  1994
#
#    rating  vote_count                                            summary  \
# 0     9.3     2333043  Two imprisoned men bond over a number of years...
#
#                 production_1 production_2        director      writer_1  ...  \
# 0  Castle Rock Entertainment               Frank Darabont  Stephen King  ...
#
#   language_3  budget gross_worldwide Rated Runtime  \
# 0             2500.0       2881.7291     R    142
#
#                                               Awards  \
# 0  Nominated for 7 Oscars. Another 19 wins & 30 n...
#
#                                               Poster     imdbID  \
# 0  https://images-na.ssl-images-amazon.com/images...  tt0111161
#
#                                            tomatoURL          DVD
# 0  http://www.rottentomatoes.com/m/shawshank_rede...  27 Jan 1998
#
# [1 rows x 33 columns]

# %%
#df['budget'] = pd.to_numeric(df['budget'])

# %%
#df['budget'] = df['budget'].astype(int(float))

# %%
df.insert(loc=4, column ='profit', value=df['gross_worldwide']-df['budget'])
df.head()
# Out:
#                       Title                                    url  year  \
# 0  The Shawshank Redemption  https://www.imdb.com/title/tt0111161/  1994
# 1             The Godfather  https://www.imdb.com/title/tt0068646/  1972
# 2    The Godfather: Part II  https://www.imdb.com/title/tt0071562/  1974
# 3           The Dark Knight  https://www.imdb.com/title/tt0468569/  2008
# 4              12 Angry Men  https://www.imdb.com/title/tt0050083/  1957
#
#    rating      profit  vote_count  \
# 0     9.3    381.7291     2333043
# 1     9.2  24012.0986     1612835
# 2     9.0   3503.5783     1125471
# 3     9.0  82097.3645     2294364
# 4     9.0    -34.9424      686732
#
#                                              summary  \
# 0  Two imprisoned men bond over a number of years...
# 1  An organized crime dynasty's aging patriarch t...
# 2  The early life and career of Vito Corleone in ...
# 3  When the menace known as the Joker wreaks havo...
# ...

# %%
df['profit']
# Out:
# 0        381.7291
# 1      24012.0986
# 2       3503.5783
# 3      82097.3645
# 4        -34.9424
#           ...
# 155     -121.5725
# 156     1323.6507
# 157      104.4121
# 159    19163.9112
# 160     1489.8633
# Name: profit, Length: 155, dtype: float64

# %%
#df["budget"] = df["budget"].apply(np.int64)
#print(df.dtypes)

# %%
# Sort the dataframe with the 'profit' column as reference using the 'sort_values' function. 
#Make sure to set the argument 'ascending' to 'False'


df.sort_values(by = "profit", ascending=False, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.head(5)
# Out:
#                                            Title  \
# 0   Harry Potter and the Deathly Hallows: Part 2
# 1  The Lord of the Rings: The Return of the King
# 2                                  The Lion King
# 3                                  Jurassic Park
# 4                                    Toy Story 3
#
#                                      url  year  rating       profit  \
# 0  https://www.imdb.com/title/tt1201607/  2011     8.1  121722.3936
# 1  https://www.imdb.com/title/tt0167260/  2003     8.9  104845.6987
# 2  https://www.imdb.com/title/tt0110357/  1994     8.5  103872.0507
# 3  https://www.imdb.com/title/tt0107290/  1993     8.1   97092.7022
# 4  https://www.imdb.com/title/tt0435761/  2010     8.3   86696.9895
#
#    vote_count                                            summary  \
# 0      761144  Harry, Ron, and Hermione search for Voldemort'...
# 1     1637090  Gandalf and Aragorn lead the World of Men agai...
# ...

# %%
# Get the top 10 profitable movies by using position based indexing. Specify the rows till 10 (0-9)

top10=df.iloc[0:10]
top10
# Out:
#                                                Title  \
# 0       Harry Potter and the Deathly Hallows: Part 2
# 1      The Lord of the Rings: The Return of the King
# 2                                      The Lion King
# 3                                      Jurassic Park
# 4                                        Toy Story 3
# 5              The Lord of the Rings: The Two Towers
# 6                                       Finding Nemo
# 7                              The Dark Knight Rises
# 8                                    The Dark Knight
# 9  The Lord of the Rings: The Fellowship of the Ring
#
#                                      url  year  rating       profit  \
# 0  https://www.imdb.com/title/tt1201607/  2011     8.1  121722.3936
# 1  https://www.imdb.com/title/tt0167260/  2003     8.9  104845.6987
# 2  https://www.imdb.com/title/tt0110357/  1994     8.5  103872.0507
# 3  https://www.imdb.com/title/tt0107290/  1993     8.1   97092.7022
# ...

# %%
plt.figure(figsize=(20,7))
sns.scatterplot(top10['budget'],top10['profit'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Style / Theme setting
sns.set_style("whitegrid")

#Plot profit vs budget

plt.figure(figsize=[10,12])

plotProfitBudget=sns.jointplot(data=top10,x="budget", y='profit', height=8, ratio=8, color="Red", kind="reg")
plt.subplots_adjust(top=0.9)
plotProfitBudget.fig.suptitle('Scatter plot of Budget and Profit',fontsize= 18,fontweight= 7,color='Green')

plotProfitBudget.set_axis_labels('Budget', 'Profit', fontdict={'fontsize': 15,'fontweight': 6,'color': 'Green'})

plt.show()

# %%
top10[['Title','budget','profit','star_1']]
# Out:
#                                                Title   budget       profit  \
# 0       Harry Potter and the Deathly Hallows: Part 2  12500.0  121722.3936
# 1      The Lord of the Rings: The Return of the King   9400.0  104845.6987
# 2                                      The Lion King   4500.0  103872.0507
# 3                                      Jurassic Park   6300.0   97092.7022
# 4                                        Toy Story 3  20000.0   86696.9895
# 5              The Lord of the Rings: The Two Towers   9400.0   84939.6133
# 6                                       Finding Nemo   9400.0   84635.0194
# 7                              The Dark Knight Rises  25000.0   83114.1435
# 8                                    The Dark Knight  18500.0   82097.3645
# 9  The Lord of the Rings: The Fellowship of the Ring   9300.0   79515.9092
#
#               star_1
# 0   Daniel Radcliffe
# 1        Elijah Wood
# 2  Matthew Broderick
# 3          Sam Neill
# 4          Tom Hanks
# ...

# %%
#recipe of a blockbluster movie

import statistics as st
st.mode(top10['genre_1'])
# Out:
# 'Action'

# %%
#recipe of a blockbluster movie
st.mode(top10['star_1'])
# Out:
# 'Elijah Wood'

# %%
#recipe of a blockbluster movie
st.mode(top10['budget'])
# Out:
# 9400.0

# %%
#recipe of a blockbluster movie
st.mode(top10['Runtime'])
# Out:
# '130 '

# %%
#recipe of a blockbluster movie
st.mode(top10['director'])
# Out:
# 'Peter Jackson'

# %%
#we want to know the most talked about movie
#we want to see a movie name with highest vote count
#we can have the sort value by desc in vote count and extract name and vote

#print(df['vote_count'].max)

# %%
df.sort_values(by='vote_count',ascending=False, inplace = True)
df[['Title','rating','vote_count']].iloc[0]
# Out:
# Title         The Shawshank Redemption
# rating                             9.3
# vote_count                     2333043
# Name: 121, dtype: object

# %%
#now we want to see relation between votecount and rating

# %%
df['vote_count'] = (df['vote_count']/1000).round(2)

# %%
df['vote_count']
# Out:
# 121    2333.04
# 8      2294.36
# 11     2058.33
# 89     1847.62
# 49     1819.38
#         ...
# 149     108.33
# 146     106.65
# 135     100.58
# 130      90.44
# 148      69.18
# Name: vote_count, Length: 155, dtype: float64

# %% [markdown]
# ## **now a scatterplot between vote and rating**

# %%
#now a scatterplot between vote and rating

plt.figure(figsize=(20,7))
sns.scatterplot(df['vote_count'],df['rating'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Style / Theme setting
sns.set_style("whitegrid")

#Plot vote vs rating

plt.figure(figsize=[10,12])

plotProfitBudget=sns.jointplot(data=df,x="vote_count", y='rating', height=8, ratio=8, color="Red", kind="reg")
plt.subplots_adjust(top=0.9)
plotProfitBudget.fig.suptitle('Scatter plot of Budget and Profit',fontsize= 18,fontweight= 7,color='Green')

plotProfitBudget.set_axis_labels('Budget', 'Profit', fontdict={'fontsize': 15,'fontweight': 6,'color': 'Green'})

plt.show()
